# %% [markdown]
# # Task

# %% [markdown]
# Step 1 - Create a table "EmployeeData" with attributes "ID", "NAME", and "DateOfJoining", Make ID as Primary Key. And Insert 10 values atleast.

# %% [markdown]
# Step 2 - fetch the data from "EmployeeData" table and store it in a variable called "DF"

# %% [markdown]
# Step 3 - Perform basic data analysis on this data like
# .describe() for statistical analysis
# .info() for discriptive analysis
# .head() for first 5 values
# .tail(3) for last 3 values .... etc.

# %% [markdown]
# # Solutions

# %% [markdown]
# ## Step 1

# %% [markdown]
# ### Connecting to a Database

# %%
import oracledb 

username = "system"  
password = "password"  
host = "localhost" 
port = 1521  
service_name = "free" 
connection_string = f"{username}/{password}@{host}:{port}/{service_name}"
connection = oracledb.connect(connection_string)
print("Connection established.")
# Out:
# Connection established.

# %% [markdown]
# ### Creating the required table

# %%
cursor = connection.cursor()
